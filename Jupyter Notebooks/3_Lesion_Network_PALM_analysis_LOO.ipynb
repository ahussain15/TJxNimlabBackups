# %% [markdown]
# # Perform a Lesion Network Mapping GLM using FSL's PALM
#
# ### Authors: Alexander Cohen, Christopher Lin
#
# Use this to run/test a statistical model (e.g., regression or T-tests) on lesion network maps (or lesions alone!) using PALM, potentially taking into account specific covariates of interest and/or nuisance regressors.
#
# Notes:
# - To best use this notebook, you should be familar with GLM design and Contrast Matrix design. See this webpage to get started:
# [FSL's GLM page](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM)
# - This notebook is a combination of the old PALM Notebooks and Christopher's palm_analysis notebooks (does the same thing) and requires the NIMLAB Python 3 environment as a kernel. Directions are on the [NIMLAB software_env README.md](https://github.com/nimlab/software_env)
# - You will need a csv file that provides the paths to your fcMaps, usually created from the [Preprocessing](https://github.com/nimlab/templates/blob/master/py3_notebooks/1_Preprocessing_LesionQA_fcGen_XNATupload.ipynb) or [xnat_grabber](https://github.com/nimlab/templates/blob/master/xnat_grabber.ipynb) notebooks.
# - Christopher wrote up a really nice description of how to modify code to set up your design matrix within the notebook here: [PALM-Analysis](https://github.com/nimlab/documentation/wiki/PALM-Analyses)
# - I would also recommend reviewing Fred's [slides](https://github.com/nimlab/documentation/blob/master/presentations/presentation_palm_multidataset_analyses_labmeeting_13.4.2020.pdf) from his May 2020 lab meeting For details regarding the difference between implementing a random effects and fixed effects analysis and use of exchangeability blocks

# %%
## Packages and environmental settings:

##Packages:
import os
import sys
import shutil
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import pyplot as plt
from nimlab import software as sf
from nilearn import image

# %matplotlib inline

# %% [markdown]
# # Input/Output Setup

# %% [markdown]
# ### 1. Provide your email address for future reference:

# %%
# Enter your email address here in quotes:
creator_email = "alexander.cohen2@childrens.harvard.edu"

# %% [markdown]
# ### 2. Where are your data? and where do you want the results to go?
# NOTES:
# - `dataset_csv` is the csv file created from the `Preprocessing` or `xnat_grabber` notebooks that points to your Lesions and fcMaps (will also work with older csv files from `xnat_gate`).
# - If you are comparing multiple datasets, your csv should contain both, i.e., specify both in xnat_grabber, or just concatenate the files in excel, etc...
# - Don't worry about any covariate variables yet, we'll get to that below...

# %%
# Specify the path to your dataset.csv file

# dataset_csv = "your_dataset_csv_file.csv"
# output_dir = "3_PALM_Analysis_of_datasetA_and_covariateB"

dataset_csv = "mgh_palm.csv"
output_dir = "mgh_palm"

clean_df = pd.read_csv(dataset_csv)

### Code to remove rows where a particular column has no data:
# clean_df.dropna(how='any', subset=['language_f'],inplace=True)

# Specify which files are to be used as input:
# This is usually 'func_T' but the other files could be used as well
# ('Lesion', 'AvgR', 'AvgR_Fz', or 'func_T')
input_imgs = clean_df['filenames']

working_dir = os.path.join(output_dir,"palm_config")
if not os.path.exists(working_dir):
    os.makedirs(working_dir)

print("I found", len(clean_df), "participants in", len(clean_df.dataset.unique()),"different datasets:",clean_df.dataset.unique())
print("")
print("Results will be stored in a sub-directory named: ",output_dir)
display(clean_df)
# Out:
# I found 488 participants in 1 different datasets: ['MGH']
#
# Results will be stored in a sub-directory named:  mgh_palm
#     dataset  subject  mRS  NIHSS                           filenames
# 0       MGH        1    0      2  mgh_avgr_fz/subject001_AvgR_Fz.nii
# 1       MGH        2    1      7  mgh_avgr_fz/subject002_AvgR_Fz.nii
# 2       MGH        3    6     31  mgh_avgr_fz/subject003_AvgR_Fz.nii
# 3       MGH        4    1      2  mgh_avgr_fz/subject004_AvgR_Fz.nii
# 4       MGH        5    1      1  mgh_avgr_fz/subject005_AvgR_Fz.nii
# ..      ...      ...  ...    ...                                 ...
# 483     MGH      486    1      4  mgh_avgr_fz/subject486_AvgR_Fz.nii
# 484     MGH      487    0      1  mgh_avgr_fz/subject487_AvgR_Fz.nii
# 485     MGH      488    6     15  mgh_avgr_fz/subject488_AvgR_Fz.nii
# 486     MGH      489    0      0  mgh_avgr_fz/subject489_AvgR_Fz.nii
# 487     MGH      490    6      9  mgh_avgr_fz/subject490_AvgR_Fz.nii
#
# [488 rows x 5 columns]

# %% [markdown]
# ### 3. Create a design matrix
#
# NOTES:
# - The design matrix tells PALM about the statistical structure of your data
# - Rows = subjects/maps/observations
# - Columns = "explanatory variables" or EVs
#     - EVs can be independent binary or continuous variables that you are interested in studying.
#     - EVs can also be 'nuisance' variables you are not interested in (like lesion size, or type of data).
#     - By including any EVs you think could effect the fcMaps, your statistical estimate for the EV of interest (your 'contrast' of interest) will be more specific and less likely to be due to a confound, but there are specific reasons to *not* include a nuisance variable from time to time.
# - Examples:
#     - [Two Sample T-Test](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM#Two-Group_Difference_.28Two-Sample_Unpaired_T-Test.29)
#     - [One Sample with Covariate](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM#Single-Group_Average_with_Additional_Covariate)
#
# Only run **ONE** of the following two sets of cells depending on how you want to create your design matrix:
# - If you want to manually edit your design matrix, i.e., in Excel, choose **Option 1**.
# - If you want to generate your design matrix with code, i.e., using Christopher's [examples](https://github.com/nimlab/documentation/wiki/PALM-Analyses), choose **Option 2**.
# - **Both** options allow you to automatically add lesion sizes.

# %% [markdown]
# ### OPTION ONE (part A) - If you are going to manually add your EVs, first use this cell:
# NOTE: If a `dataset_phenotype.csv` already exists (you are re-running this notebook), the file will NOT be overwritten. If you want a new template to be created, delete the file first.

# %%
# This cell will create a template phenotype file that lists your files and the dataset and subject names:

# Do you want me to add lesion sizes to the phenotype file for you?
add_lesion_sizes = False

phenotype_csv = os.path.splitext(dataset_csv)[0]+"_phenotype.csv"

if not os.path.exists(phenotype_csv):
    template_design_matrix = clean_df[['dataset','subject']].copy()
    template_design_matrix.insert(0,'files',input_imgs)
    if add_lesion_sizes:
        lesion_sizes=[]
        for lesion in tqdm(clean_df.Lesion):
            lesion_sizes.append(np.count_nonzero(np.nan_to_num(image.load_img(lesion, dtype="int16").get_fdata())))
        template_design_matrix['lesion_sizes']=lesion_sizes
    template_design_matrix.to_csv(phenotype_csv, index=False)
    print("")
    print("A Template Design Matrix (with labels) has been created at",phenotype_csv)
else:
    print("There is already a file named:",phenotype_csv)
    print("If you want to make a new one, delete this file first and re-run this cell.")
# Out:
# A Template Design Matrix (with labels) has been created at mgh_palm_phenotype.csv

# %% [markdown]
# ### OPTION ONE (part B) - After you have manually added your EVs, then use this cell to load your modified phenotype.csv:
# NOTE: Don't change the name, just edit/modify the file in place, and this code will load the content

# %%
# Load your modified phenotype file and create a design matrix from it:
design_matrix = pd.read_csv(phenotype_csv)
ordered_input_imgs=design_matrix['files']
design_matrix = design_matrix.drop(columns=['files','dataset','subject'])

# %% [markdown]
# ### OPTION TWO - If you are going to construct your design matrix using code, uncomment (Cmd+/ or Control+/) and use this cell:
#
# The instructions/examples Christopher put together are on [GitHub](https://github.com/nimlab/documentation/wiki/PALM-Analyses), and the possible patterns are listed on the FSL [GLM website](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM).
#
# - Typical Examples:
#     - [Two Sample T-Test](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM#Two-Group_Difference_.28Two-Sample_Unpaired_T-Test.29)
#     - [One Sample with Covariate](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM#Single-Group_Average_with_Additional_Covariate)

# %%
# # Modify this cell according to the documentation page:
# # https://github.com/nimlab/documentation/wiki/PALM-Analyses

# # Keep these two lines:
# design_matrix = pd.DataFrame()
# ordered_input_imgs=input_imgs


# coding_key = {"Corbetta_Lesions": 1}
# design_matrix["Intercept"] = clean_df['dataset'].replace(coding_key)

# design_matrix["language_f"] = clean_df['language_f'].copy()


# # Do you want to also add lesion sizes to the design matrix?
# add_lesion_sizes = True


# if add_lesion_sizes:
#     lesion_sizes=[]
#     for lesion in tqdm(clean_df.Lesion):
#         lesion_sizes.append(np.count_nonzero(np.nan_to_num(image.load_img(lesion, dtype="int16").get_fdata())))
#     design_matrix['lesion_sizes']=lesion_sizes

# %% [markdown]
# ### 3b. Mean-Center your covariates
# NOTES:
# - This is described [here](http://mumford.fmripower.org/mean_centering/) and on the FSL FSL [GLM website](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM).
# - Add lines as necessary for your covariates.
# - Your 'dummy' variables (0 vs 1) for group membership do not need to bee mean-centered

# %%
### mean center any continous variables
# design_matrix['covariateA'] = design_matrix['covariateA'].sub(design_matrix['covariateA'].mean())  
# design_matrix['covariateB'] = design_matrix['covariateB'].sub(design_matrix['covariateB'].mean())  

### mean center the lesion sizes AND divide by 1000 to get the numbers ~0-100s or so:
# (According to Anderson, having values in the 10,000s could cause statistical weirdness...)
# design_matrix['lesion_sizes'] = design_matrix['lesion_sizes'].sub(design_matrix['lesion_sizes'].mean()).div(1000)

# %% [markdown]
# ### 4. Show me what the design matrix looks like

# %%
print("I found",len(design_matrix. columns),"EVs IN THIS ORDER:",list(design_matrix.columns))

if 'lesion_sizes' in design_matrix.columns:
    fig, axs = plt.subplots(1,2,sharey=True)
    a1 = axs[0].imshow(design_matrix.drop(columns=['lesion_sizes']), aspect='auto')
    a2 = axs[1].imshow(design_matrix.filter(['lesion_sizes']), aspect='auto')
    plt.colorbar(a1,ax=axs[0])
    plt.colorbar(a2,ax=axs[1])
    print("Plotting the lesion sizes separately b/c they overwhelm the 1s and 0s")
else:
    plt.matshow(design_matrix, aspect='auto')
    plt.colorbar()
# Out:
# I found 2 EVs IN THIS ORDER: ['int', 'nihss']

# %% [markdown]
# ### 5. Now, Create a contrast matrix
#
# NOTES:
# - Each 'contrast' is a statistical test where you are asking the question: **where** in the brain do the values behave like the single EV, or combination of EVs, that you specifiy in your contrast. This is also discussed on the FSL [GLM website](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/GLM).
# - Each 'contrast' is a short list of numbers, one per EV, typically +1,0,-1 that are **in the same order as the columns of your design matrix**.
# - There are different ways to organize your design matrix and contrast matrix to achieve the same goals, this is where collaborating with someone who has done this before is important to make sure you are 'asking' the question you think you are asking.

# %%
# Modify this cell according to the documentation page:
# https://github.com/nimlab/documentation/wiki/PALM-Analyses

contrast_df = pd.DataFrame()

contrast_df['nihss'] = [0, 1]

contrast_matrix = contrast_df.T
contrast_matrix.columns = design_matrix.columns
print("Each row is a contrast, each column is an EV:")
print("")
display(contrast_matrix)
# Out:
# Each row is a contrast, each column is an EV:
#        int  nihss
# nihss    0      1

# %% [markdown]
# ### 5b. (Optional) Generate exchangeability blocks if needed
# NOTES:
# - This is optional and for when you are doing a 'meta-analysis' of multiple data types, e.g. strokes and DBS sites
# - This is a column of integers that can usually be generated from the dataset names. Details on the [PALM website](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/PALM/ExchangeabilityBlocks)
# - To use this, add the following to the `call_palm` command below `eb=eb_matrix`.

# %%
### This is just an example, you will have to edit to adapt to your data, 
### but it should be integers, starting with 1,2,3....

# coding_key = {"Prosopagnosia_w_Yeo1000": 1,
#              "Corbetta_Lesions": 1,
#              "DBS_dataset": 2
#              }

# eb_matrix = pd.DataFrame()
# eb_matrix = clean_df['dataset'].replace(coding_key)
# display(eb_matrix)

# %% [markdown]
# ### 6. FINALLY, Run PALM
#
# NOTES:
# - This can take awhile depending on the number of subjects and the number of contrasts, make sure you are running this in a 'protected' session, i.e., jupyter was run in a `tmux` session or an onDemand session.
# - There are options for the `call_palm` function to allow for getting tfce-fwe results, using exchangeability blocks, 1-p, etc... See the documentation here: [GitHub](https://github.com/nimlab/documentation/wiki/PALM-Analyses)
#     - `accel = "tail"` only applies to the FWE results, not the FDR or uncorrected results.
#     - `corrcon_flag = True` does FWER-correction across all contrasts, taking into account any dependency that may exist between these contrasts.
#     - **The default is to save 1-p maps**, but set `save_1p=False` and `logp=True` to instead save **-log10(p) maps**, i.e., 0.05 ~ 1.3, 0.01 ~ 2, 0.001 ~3, etc... which is **great** for visualization
#     - ~5000 permutations is considered standard, running less, like ~1000 with tail acceleration on can be useful for testing, but *the uncorrected p values can be misleading* (more iterations = more precision, not more significance)

# %%
# %env PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/usr/lib/fsl/5.0:/cluster/2021ahussain/usr/share/fsl:/cluster/2021ahussain/palm:/cluster/2021ahussain/.local/bin:/cluster/2021ahussain/bin:/cluster/2021ahussain/usr/share/fsl/5.0:/cluster/2021ahussain/palm:/cluster/2021ahussain/usr/share/fsl/5.0:palm"
# Out:
# env: PATH="/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/usr/lib/fsl/5.0:/cluster/2021ahussain/usr/share/fsl:/cluster/2021ahussain/palm:/cluster/2021ahussain/.local/bin:/cluster/2021ahussain/bin:/cluster/2021ahussain/usr/share/fsl/5.0:/cluster/2021ahussain/palm:/cluster/2021ahussain/usr/share/fsl/5.0:palm"

# %%
# Edit this according to documentation page

# Current best default settings:
# for i in range(0, design_matrix.shape[0]):
for i in range(0, design_matrix.shape[0]):
    loo_working_dir = working_dir + "/working_drop_index_" + str(i) + "/" 
    loo_output_dir = output_dir + "/output_drop_index_" + str(i) + "/" 
    os.makedirs(loo_working_dir,exist_ok=True)
    os.makedirs(loo_output_dir,exist_ok=True)
    sf.call_palm(ordered_input_imgs.drop(i),
                 design_matrix.drop(i),
                 contrast_matrix,
                 loo_working_dir,
                 loo_output_dir,
                 1000,
                 accel="tail",
                 eb=None,
                 mask="",
                 save_1p=True,
                 logp=False,
                 tfce=False,
                 ise_flag=False,
                 two_tailed_flag=True,
                 corrcon_flag=False,
                 fdr_flag=False,
                 cluster_submit="erisone_script")

# Settings that are more consistent with prior usage:
# sf.call_palm(ordered_input_imgs,
#              design_matrix,
#              contrast_matrix,
#              working_dir,
#              output_dir,
#              1000,
#              tfce=True,
#              fdr_flag=True,
#              accel="tail")
# Out:
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_0//concat.nii -o year_loo/output_drop_index_0/ -d year_loo/palm_config/working_drop_index_0//design.mat -t year_loo/palm_config/working_drop_index_0//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_0//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_0//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_1//concat.nii -o year_loo/output_drop_index_1/ -d year_loo/palm_config/working_drop_index_1//design.mat -t year_loo/palm_config/working_drop_index_1//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_1//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_1//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_2//concat.nii -o year_loo/output_drop_index_2/ -d year_loo/palm_config/working_drop_index_2//design.mat -t year_loo/palm_config/working_drop_index_2//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_2//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_2//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_3//concat.nii -o year_loo/output_drop_index_3/ -d year_loo/palm_config/working_drop_index_3//design.mat -t year_loo/palm_config/working_drop_index_3//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_3//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_3//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_4//concat.nii -o year_loo/output_drop_index_4/ -d year_loo/palm_config/working_drop_index_4//design.mat -t year_loo/palm_config/working_drop_index_4//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_4//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_4//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_5//concat.nii -o year_loo/output_drop_index_5/ -d year_loo/palm_config/working_drop_index_5//design.mat -t year_loo/palm_config/working_drop_index_5//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_5//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_5//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_6//concat.nii -o year_loo/output_drop_index_6/ -d year_loo/palm_config/working_drop_index_6//design.mat -t year_loo/palm_config/working_drop_index_6//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_6//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_6//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_7//concat.nii -o year_loo/output_drop_index_7/ -d year_loo/palm_config/working_drop_index_7//design.mat -t year_loo/palm_config/working_drop_index_7//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_7//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_7//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_8//concat.nii -o year_loo/output_drop_index_8/ -d year_loo/palm_config/working_drop_index_8//design.mat -t year_loo/palm_config/working_drop_index_8//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_8//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_8//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_9//concat.nii -o year_loo/output_drop_index_9/ -d year_loo/palm_config/working_drop_index_9//design.mat -t year_loo/palm_config/working_drop_index_9//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_9//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_9//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_10//concat.nii -o year_loo/output_drop_index_10/ -d year_loo/palm_config/working_drop_index_10//design.mat -t year_loo/palm_config/working_drop_index_10//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_10//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_10//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_11//concat.nii -o year_loo/output_drop_index_11/ -d year_loo/palm_config/working_drop_index_11//design.mat -t year_loo/palm_config/working_drop_index_11//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_11//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_11//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_12//concat.nii -o year_loo/output_drop_index_12/ -d year_loo/palm_config/working_drop_index_12//design.mat -t year_loo/palm_config/working_drop_index_12//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_12//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_12//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_13//concat.nii -o year_loo/output_drop_index_13/ -d year_loo/palm_config/working_drop_index_13//design.mat -t year_loo/palm_config/working_drop_index_13//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_13//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_13//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_14//concat.nii -o year_loo/output_drop_index_14/ -d year_loo/palm_config/working_drop_index_14//design.mat -t year_loo/palm_config/working_drop_index_14//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_14//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_14//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_15//concat.nii -o year_loo/output_drop_index_15/ -d year_loo/palm_config/working_drop_index_15//design.mat -t year_loo/palm_config/working_drop_index_15//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_15//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_15//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_16//concat.nii -o year_loo/output_drop_index_16/ -d year_loo/palm_config/working_drop_index_16//design.mat -t year_loo/palm_config/working_drop_index_16//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_16//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_16//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_17//concat.nii -o year_loo/output_drop_index_17/ -d year_loo/palm_config/working_drop_index_17//design.mat -t year_loo/palm_config/working_drop_index_17//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_17//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_17//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_18//concat.nii -o year_loo/output_drop_index_18/ -d year_loo/palm_config/working_drop_index_18//design.mat -t year_loo/palm_config/working_drop_index_18//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_18//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_18//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_19//concat.nii -o year_loo/output_drop_index_19/ -d year_loo/palm_config/working_drop_index_19//design.mat -t year_loo/palm_config/working_drop_index_19//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_19//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_19//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_20//concat.nii -o year_loo/output_drop_index_20/ -d year_loo/palm_config/working_drop_index_20//design.mat -t year_loo/palm_config/working_drop_index_20//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_20//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_20//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_21//concat.nii -o year_loo/output_drop_index_21/ -d year_loo/palm_config/working_drop_index_21//design.mat -t year_loo/palm_config/working_drop_index_21//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_21//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_21//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_22//concat.nii -o year_loo/output_drop_index_22/ -d year_loo/palm_config/working_drop_index_22//design.mat -t year_loo/palm_config/working_drop_index_22//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_22//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_22//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_23//concat.nii -o year_loo/output_drop_index_23/ -d year_loo/palm_config/working_drop_index_23//design.mat -t year_loo/palm_config/working_drop_index_23//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_23//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_23//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_24//concat.nii -o year_loo/output_drop_index_24/ -d year_loo/palm_config/working_drop_index_24//design.mat -t year_loo/palm_config/working_drop_index_24//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_24//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_24//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_25//concat.nii -o year_loo/output_drop_index_25/ -d year_loo/palm_config/working_drop_index_25//design.mat -t year_loo/palm_config/working_drop_index_25//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_25//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_25//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_26//concat.nii -o year_loo/output_drop_index_26/ -d year_loo/palm_config/working_drop_index_26//design.mat -t year_loo/palm_config/working_drop_index_26//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_26//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_26//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_27//concat.nii -o year_loo/output_drop_index_27/ -d year_loo/palm_config/working_drop_index_27//design.mat -t year_loo/palm_config/working_drop_index_27//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_27//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_27//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_28//concat.nii -o year_loo/output_drop_index_28/ -d year_loo/palm_config/working_drop_index_28//design.mat -t year_loo/palm_config/working_drop_index_28//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_28//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_28//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_29//concat.nii -o year_loo/output_drop_index_29/ -d year_loo/palm_config/working_drop_index_29//design.mat -t year_loo/palm_config/working_drop_index_29//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_29//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_29//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_30//concat.nii -o year_loo/output_drop_index_30/ -d year_loo/palm_config/working_drop_index_30//design.mat -t year_loo/palm_config/working_drop_index_30//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_30//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_30//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_31//concat.nii -o year_loo/output_drop_index_31/ -d year_loo/palm_config/working_drop_index_31//design.mat -t year_loo/palm_config/working_drop_index_31//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_31//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_31//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_32//concat.nii -o year_loo/output_drop_index_32/ -d year_loo/palm_config/working_drop_index_32//design.mat -t year_loo/palm_config/working_drop_index_32//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_32//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_32//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_33//concat.nii -o year_loo/output_drop_index_33/ -d year_loo/palm_config/working_drop_index_33//design.mat -t year_loo/palm_config/working_drop_index_33//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_33//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_33//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_34//concat.nii -o year_loo/output_drop_index_34/ -d year_loo/palm_config/working_drop_index_34//design.mat -t year_loo/palm_config/working_drop_index_34//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_34//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_34//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_35//concat.nii -o year_loo/output_drop_index_35/ -d year_loo/palm_config/working_drop_index_35//design.mat -t year_loo/palm_config/working_drop_index_35//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_35//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_35//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_36//concat.nii -o year_loo/output_drop_index_36/ -d year_loo/palm_config/working_drop_index_36//design.mat -t year_loo/palm_config/working_drop_index_36//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_36//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_36//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_37//concat.nii -o year_loo/output_drop_index_37/ -d year_loo/palm_config/working_drop_index_37//design.mat -t year_loo/palm_config/working_drop_index_37//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_37//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_37//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_38//concat.nii -o year_loo/output_drop_index_38/ -d year_loo/palm_config/working_drop_index_38//design.mat -t year_loo/palm_config/working_drop_index_38//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_38//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_38//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_39//concat.nii -o year_loo/output_drop_index_39/ -d year_loo/palm_config/working_drop_index_39//design.mat -t year_loo/palm_config/working_drop_index_39//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_39//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_39//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_40//concat.nii -o year_loo/output_drop_index_40/ -d year_loo/palm_config/working_drop_index_40//design.mat -t year_loo/palm_config/working_drop_index_40//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_40//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_40//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_41//concat.nii -o year_loo/output_drop_index_41/ -d year_loo/palm_config/working_drop_index_41//design.mat -t year_loo/palm_config/working_drop_index_41//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_41//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_41//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_42//concat.nii -o year_loo/output_drop_index_42/ -d year_loo/palm_config/working_drop_index_42//design.mat -t year_loo/palm_config/working_drop_index_42//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_42//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_42//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_43//concat.nii -o year_loo/output_drop_index_43/ -d year_loo/palm_config/working_drop_index_43//design.mat -t year_loo/palm_config/working_drop_index_43//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_43//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_43//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_44//concat.nii -o year_loo/output_drop_index_44/ -d year_loo/palm_config/working_drop_index_44//design.mat -t year_loo/palm_config/working_drop_index_44//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_44//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_44//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_45//concat.nii -o year_loo/output_drop_index_45/ -d year_loo/palm_config/working_drop_index_45//design.mat -t year_loo/palm_config/working_drop_index_45//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_45//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_45//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_46//concat.nii -o year_loo/output_drop_index_46/ -d year_loo/palm_config/working_drop_index_46//design.mat -t year_loo/palm_config/working_drop_index_46//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_46//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_46//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_47//concat.nii -o year_loo/output_drop_index_47/ -d year_loo/palm_config/working_drop_index_47//design.mat -t year_loo/palm_config/working_drop_index_47//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_47//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_47//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_48//concat.nii -o year_loo/output_drop_index_48/ -d year_loo/palm_config/working_drop_index_48//design.mat -t year_loo/palm_config/working_drop_index_48//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_48//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_48//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_49//concat.nii -o year_loo/output_drop_index_49/ -d year_loo/palm_config/working_drop_index_49//design.mat -t year_loo/palm_config/working_drop_index_49//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_49//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_49//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_50//concat.nii -o year_loo/output_drop_index_50/ -d year_loo/palm_config/working_drop_index_50//design.mat -t year_loo/palm_config/working_drop_index_50//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_50//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_50//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_51//concat.nii -o year_loo/output_drop_index_51/ -d year_loo/palm_config/working_drop_index_51//design.mat -t year_loo/palm_config/working_drop_index_51//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_51//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_51//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_52//concat.nii -o year_loo/output_drop_index_52/ -d year_loo/palm_config/working_drop_index_52//design.mat -t year_loo/palm_config/working_drop_index_52//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_52//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_52//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_53//concat.nii -o year_loo/output_drop_index_53/ -d year_loo/palm_config/working_drop_index_53//design.mat -t year_loo/palm_config/working_drop_index_53//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_53//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_53//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_54//concat.nii -o year_loo/output_drop_index_54/ -d year_loo/palm_config/working_drop_index_54//design.mat -t year_loo/palm_config/working_drop_index_54//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_54//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_54//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_55//concat.nii -o year_loo/output_drop_index_55/ -d year_loo/palm_config/working_drop_index_55//design.mat -t year_loo/palm_config/working_drop_index_55//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_55//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_55//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_56//concat.nii -o year_loo/output_drop_index_56/ -d year_loo/palm_config/working_drop_index_56//design.mat -t year_loo/palm_config/working_drop_index_56//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_56//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_56//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_57//concat.nii -o year_loo/output_drop_index_57/ -d year_loo/palm_config/working_drop_index_57//design.mat -t year_loo/palm_config/working_drop_index_57//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_57//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_57//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_58//concat.nii -o year_loo/output_drop_index_58/ -d year_loo/palm_config/working_drop_index_58//design.mat -t year_loo/palm_config/working_drop_index_58//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_58//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_58//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_59//concat.nii -o year_loo/output_drop_index_59/ -d year_loo/palm_config/working_drop_index_59//design.mat -t year_loo/palm_config/working_drop_index_59//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_59//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_59//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_60//concat.nii -o year_loo/output_drop_index_60/ -d year_loo/palm_config/working_drop_index_60//design.mat -t year_loo/palm_config/working_drop_index_60//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_60//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_60//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_61//concat.nii -o year_loo/output_drop_index_61/ -d year_loo/palm_config/working_drop_index_61//design.mat -t year_loo/palm_config/working_drop_index_61//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_61//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_61//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_62//concat.nii -o year_loo/output_drop_index_62/ -d year_loo/palm_config/working_drop_index_62//design.mat -t year_loo/palm_config/working_drop_index_62//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_62//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_62//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_63//concat.nii -o year_loo/output_drop_index_63/ -d year_loo/palm_config/working_drop_index_63//design.mat -t year_loo/palm_config/working_drop_index_63//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_63//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_63//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_64//concat.nii -o year_loo/output_drop_index_64/ -d year_loo/palm_config/working_drop_index_64//design.mat -t year_loo/palm_config/working_drop_index_64//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_64//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_64//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_65//concat.nii -o year_loo/output_drop_index_65/ -d year_loo/palm_config/working_drop_index_65//design.mat -t year_loo/palm_config/working_drop_index_65//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_65//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_65//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_66//concat.nii -o year_loo/output_drop_index_66/ -d year_loo/palm_config/working_drop_index_66//design.mat -t year_loo/palm_config/working_drop_index_66//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_66//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_66//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_67//concat.nii -o year_loo/output_drop_index_67/ -d year_loo/palm_config/working_drop_index_67//design.mat -t year_loo/palm_config/working_drop_index_67//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_67//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_67//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_68//concat.nii -o year_loo/output_drop_index_68/ -d year_loo/palm_config/working_drop_index_68//design.mat -t year_loo/palm_config/working_drop_index_68//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_68//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_68//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_69//concat.nii -o year_loo/output_drop_index_69/ -d year_loo/palm_config/working_drop_index_69//design.mat -t year_loo/palm_config/working_drop_index_69//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_69//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_69//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_70//concat.nii -o year_loo/output_drop_index_70/ -d year_loo/palm_config/working_drop_index_70//design.mat -t year_loo/palm_config/working_drop_index_70//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_70//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_70//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_71//concat.nii -o year_loo/output_drop_index_71/ -d year_loo/palm_config/working_drop_index_71//design.mat -t year_loo/palm_config/working_drop_index_71//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_71//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_71//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_72//concat.nii -o year_loo/output_drop_index_72/ -d year_loo/palm_config/working_drop_index_72//design.mat -t year_loo/palm_config/working_drop_index_72//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_72//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_72//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_73//concat.nii -o year_loo/output_drop_index_73/ -d year_loo/palm_config/working_drop_index_73//design.mat -t year_loo/palm_config/working_drop_index_73//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_73//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_73//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_74//concat.nii -o year_loo/output_drop_index_74/ -d year_loo/palm_config/working_drop_index_74//design.mat -t year_loo/palm_config/working_drop_index_74//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_74//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_74//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_75//concat.nii -o year_loo/output_drop_index_75/ -d year_loo/palm_config/working_drop_index_75//design.mat -t year_loo/palm_config/working_drop_index_75//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_75//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_75//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_76//concat.nii -o year_loo/output_drop_index_76/ -d year_loo/palm_config/working_drop_index_76//design.mat -t year_loo/palm_config/working_drop_index_76//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_76//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_76//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_77//concat.nii -o year_loo/output_drop_index_77/ -d year_loo/palm_config/working_drop_index_77//design.mat -t year_loo/palm_config/working_drop_index_77//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_77//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_77//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_78//concat.nii -o year_loo/output_drop_index_78/ -d year_loo/palm_config/working_drop_index_78//design.mat -t year_loo/palm_config/working_drop_index_78//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_78//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_78//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_79//concat.nii -o year_loo/output_drop_index_79/ -d year_loo/palm_config/working_drop_index_79//design.mat -t year_loo/palm_config/working_drop_index_79//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_79//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_79//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_80//concat.nii -o year_loo/output_drop_index_80/ -d year_loo/palm_config/working_drop_index_80//design.mat -t year_loo/palm_config/working_drop_index_80//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_80//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_80//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_81//concat.nii -o year_loo/output_drop_index_81/ -d year_loo/palm_config/working_drop_index_81//design.mat -t year_loo/palm_config/working_drop_index_81//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_81//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_81//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_82//concat.nii -o year_loo/output_drop_index_82/ -d year_loo/palm_config/working_drop_index_82//design.mat -t year_loo/palm_config/working_drop_index_82//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_82//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_82//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_83//concat.nii -o year_loo/output_drop_index_83/ -d year_loo/palm_config/working_drop_index_83//design.mat -t year_loo/palm_config/working_drop_index_83//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_83//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_83//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_84//concat.nii -o year_loo/output_drop_index_84/ -d year_loo/palm_config/working_drop_index_84//design.mat -t year_loo/palm_config/working_drop_index_84//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_84//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_84//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_85//concat.nii -o year_loo/output_drop_index_85/ -d year_loo/palm_config/working_drop_index_85//design.mat -t year_loo/palm_config/working_drop_index_85//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_85//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_85//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_86//concat.nii -o year_loo/output_drop_index_86/ -d year_loo/palm_config/working_drop_index_86//design.mat -t year_loo/palm_config/working_drop_index_86//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_86//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_86//submit.sh
#
#
# Time elapsed: 0 seconds
# concatenating input...
# Calling PALM with following command:
# palm -i year_loo/palm_config/working_drop_index_87//concat.nii -o year_loo/output_drop_index_87/ -d year_loo/palm_config/working_drop_index_87//design.mat -t year_loo/palm_config/working_drop_index_87//contrast.con -n 1000 -m year_loo/palm_config/working_drop_index_87//MNI152_T1_2mm_brain_mask_dil.nii -save1-p -twotail -accel tail
# Script saved to: year_loo/palm_config/working_drop_index_87//submit.sh
#
#
# Time elapsed: 0 seconds

# %% [markdown]
# Once all of your scripts and config data is generated, run the following in terminal:
# ```
# for f in <my output directory>/palm_config/working*/*.sh; do sh $f; done;
# ```
